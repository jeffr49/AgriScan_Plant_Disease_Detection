# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator


image_size = 224
input_shape = (image_size, image_size, 3)
batch_size = 32

dataset_root = "/kaggle/input/new-plant-diseases-dataset/new plant diseases dataset(augmented)/New Plant Diseases Dataset(Augmented)"
train_dir = os.path.join(dataset_root, "train")
test_dir = os.path.join(dataset_root, "valid")


train_aug = ImageDataGenerator(
    rescale=1/255.0,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.3,
    shear_range=0.3,
    horizontal_flip=True,
    fill_mode="nearest"
)

# %%
train_data = train_aug.flow_from_directory(
    train_dir, target_size=(image_size, image_size), batch_size=batch_size, class_mode="categorical"
)

test_aug = ImageDataGenerator(rescale=1/255.0)
test_data = test_aug.flow_from_directory(
    test_dir, target_size=(image_size, image_size), batch_size=batch_size, class_mode="categorical"
)
# Out:
# Found 70295 images belonging to 38 classes.
# Found 17572 images belonging to 38 classes.

# %%
base_model = keras.applications.MobileNetV2(
    weights="imagenet", include_top=False, input_shape=input_shape
)


for layer in base_model.layers[-30:]:
    layer.trainable = True

inputs = keras.Input(shape=input_shape)
x = base_model(inputs, training=True)
x = layers.GlobalAveragePooling2D()(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(128, activation="relu")(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.3)(x)
out = layers.Dense(len(train_data.class_indices), activation="softmax")(x)

model = Model(inputs, out)


model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4),
              loss="categorical_crossentropy",
              metrics=["accuracy"])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Train Model
model.fit(train_data, validation_data=test_data, epochs=5)
# Out:
# Epoch 1/5
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 1246s 545ms/step - accuracy: 0.6253 - loss: 1.4923 - val_accuracy: 0.8511 - val_loss: 0.5552
# Epoch 2/5
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 850s 386ms/step - accuracy: 0.9564 - loss: 0.1640 - val_accuracy: 0.9491 - val_loss: 0.1679
# Epoch 3/5
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 846s 384ms/step - accuracy: 0.9723 - loss: 0.0956 - val_accuracy: 0.9795 - val_loss: 0.0622
# Epoch 4/5
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 851s 386ms/step - accuracy: 0.9802 - loss: 0.0702 - val_accuracy: 0.9854 - val_loss: 0.0445
# Epoch 5/5
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 854s 387ms/step - accuracy: 0.9836 - loss: 0.0573 - val_accuracy: 0.9790 - val_loss: 0.0631

# %%
model.evaluate(test_data)
# Out:
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 31s 56ms/step - accuracy: 0.9791 - loss: 0.0658
# [0.06306931376457214, 0.9790006875991821]

# %%
model.save("plant_disease_detection.h5")

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model


model = load_model("/kaggle/working/plant_disease_detection.h5")


converter = tf.lite.TFLiteConverter.from_keras_model(model)


converter.optimizations = [tf.lite.Optimize.DEFAULT]


tflite_model = converter.convert()


with open('plant_disease_model.tflite', 'wb') as f:
    f.write(tflite_model)

print("TFLite model saved as 'plant_disease_model.tflite'")
# Out:
# Saved artifact at '/tmp/tmpms_npnxd'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   TensorSpec(shape=(None, 38), dtype=tf.float32, name=None)
# Captures:
#   140265329332592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329344032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329379104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329339456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329341744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329382624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329382976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329384384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329380688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329382272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329386672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329387024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329388256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329384912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329386320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329390544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329390896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329392304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329387200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329390192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329392832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329459792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329460672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329389136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329460144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329464544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329464896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329466128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329462784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329464192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329468416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329468768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329470176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329465072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329468064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329472464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329472816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329474224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329470704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329472112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329472992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329525152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329526032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329474928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329525504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329529904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329530256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329531488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329528144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329529552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329534128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329534480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329535888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329532368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329533776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329538176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329538528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329539936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329536416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329537824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329540288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329623456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329624336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329540464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329623808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329628208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329628560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329629792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329626448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329627856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329632256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329632608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329634016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329630496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329631904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329636304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329636656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329638064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329634544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329635952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329636832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329721760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329722640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329638768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329722112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329726512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329726864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329728096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329724752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329726160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329730560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329730912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329732320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329728800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329730208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329734784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329735136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329736544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329733024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329734432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329735312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329787472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329788352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329731792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329787824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329737072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329791168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329793632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329790288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329791696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329796096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329796448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329797856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329794336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329795744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329800144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329800496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329801904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329798384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329799792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329800672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329885600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329886480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329802608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329885952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329890352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329890704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329891936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329888592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329890000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329894400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329894752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329896160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329892640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329894048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329898448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329898800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329900208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329896688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329898096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329898976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329934752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329935632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329900912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329935104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329939504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329939856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329941088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329937744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329939152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329943552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329943904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329945312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329941792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329943200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329947600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329947952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329949360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329945840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329947248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329948128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330049440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330050320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329950064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330049792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265329949888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330053136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330055600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330052256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330053664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330058064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330058416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330059824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330056304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330057712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330062112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330062464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330063872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330060352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330061760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330062640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330131184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330132064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330065104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330131536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330135936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330135232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330137520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330134176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330135584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330139984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330140336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330141744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330138224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330139632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330144032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330144384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330145792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330142272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330143680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330146320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330213280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330214160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330146672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330213632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330218032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330218384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330219616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330216272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330217680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330221904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330222256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330223664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330218560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330221552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330225952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330226304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330227712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330224192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330225600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330226480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328263408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328264288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265330228944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328263760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328268160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328267456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328269744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328266400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328267808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328272208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328272560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328273968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328270448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328271856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328276256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328276608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328278016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328274496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328275904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328276784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328296176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328297056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328279248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328296528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328300928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328300224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328302512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328299168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328300576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328304976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328305328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328306736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328303216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328304624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328308848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328309200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328310608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328305504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328308496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328311840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265331989968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328308144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328311136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265328311312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265331345536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265331345008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265331345360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265331343600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265331344656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265331347296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140265331349408: TensorSpec(shape=(), dtype=tf.resource, name=None)
# TFLite model saved as 'plant_disease_model.tflite'
